# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("korea_charger.csv", encoding='cp949')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (13,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.columns
# Out:
# Index(['STAT_NM', 'STAT_ID', 'CHGER_ID', 'CHGER_TYPE', 'ADDR', 'LAT', 'LON',
#        'USE_TIME', 'BUSI_ID', 'BUSI_NM', 'BUSI_CALL', 'CHGER_STAT',
#        'STAT_UPD_DT', 'POWER_TYPE', 'CITY_DO_CD', 'PARKING_FREE_YN',
#        'STAT_NOTE', 'LIMIT_YN', 'LIMIT_DETAIL', 'DEL_YN', 'DEL_DETAIL'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69290 entries, 0 to 69289
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STAT_NM          69290 non-null  object
#  1   STAT_ID          69290 non-null  object
#  2   CHGER_ID         69290 non-null  int64
#  3   CHGER_TYPE       69290 non-null  int64
#  4   ADDR             69195 non-null  object
#  5   LAT              69290 non-null  float64
#  6   LON              69290 non-null  float64
#  7   USE_TIME         61477 non-null  object
#  8   BUSI_ID          69290 non-null  object
#  9   BUSI_NM          69290 non-null  object
#  10  BUSI_CALL        64306 non-null  object
#  11  CHGER_STAT       69290 non-null  int64
#  12  STAT_UPD_DT      67696 non-null  float64
#  13  POWER_TYPE       4375 non-null   object
#  14  CITY_DO_CD       69290 non-null  int64
#  15  PARKING_FREE_YN  68684 non-null  object
# ...

# %%
data.head(15)
# Out:
#              STAT_NM   STAT_ID  ...  DEL_YN  DEL_DETAIL
# 0           종묘 공영주차장  ME000001  ...       N         NaN
# 1          세종로 공영주차장  ME000002  ...       N         NaN
# 2         그랜드앰배서더 서울  ME000003  ...       N         NaN
# 3         한강진역 공영주차장  ME000004  ...       N         NaN
# 4        기아차 성동서비스센터  ME000005  ...       N         NaN
# 5   마장동사무소 앞(공중전화부스)  ME000006  ...       N         NaN
# 6           청량리롯데백화점  ME000007  ...       N         NaN
# 7            이마트 이문점  ME000008  ...       N         NaN
# 8           홈플러스 면목점  ME000010  ...       N         NaN
# 9           홈플러스 월곡점  ME000011  ...       N         NaN
# 10      성북벤처빌딩 공영주차장  ME000012  ...       N         NaN
# 11          롯데마트 삼양점  ME000013  ...       N         NaN
# 12           빅마켓 도봉점  ME000014  ...       N         NaN
# 13           이마트 은평점  ME000016  ...       N         NaN
# 14        구파발역 환승주차장  ME000017  ...       N         NaN
#
# [15 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['STAT_NM', 'STAT_ID', 'CHGER_ID', 'CHGER_TYPE', 'ADDR', 'LAT', 'LON',
#        'USE_TIME', 'BUSI_ID', 'BUSI_NM', 'BUSI_CALL', 'CHGER_STAT',
#        'STAT_UPD_DT', 'POWER_TYPE', 'CITY_DO_CD', 'PARKING_FREE_YN',
#        'STAT_NOTE', 'LIMIT_YN', 'LIMIT_DETAIL', 'DEL_YN', 'DEL_DETAIL'],
#       dtype='object')

# %%
data = data.fillna(0)
print(data)
# Out:
#            STAT_NM   STAT_ID  CHGER_ID  ...  DEL_YN DEL_DETAIL  POWER_TYPE_all
# 0         종묘 공영주차장  ME000001         1  ...       N          0        급속(50kW)
# 1        세종로 공영주차장  ME000002         1  ...       N          0        급속(50kW)
# 2       그랜드앰배서더 서울  ME000003         1  ...       N          0        급속(50kW)
# 3       한강진역 공영주차장  ME000004         1  ...       N          0        급속(50kW)
# 4      기아차 성동서비스센터  ME000005         1  ...       N          0        급속(50kW)
# ...            ...       ...       ...  ...     ...        ...             ...
# 69285  영남알프스복합웰컴센터  US200419         2  ...       N          0               0
# 69286   언양읍 행정복지센터  US200420         1  ...       N          0               0
# 69287   화봉공원 공영주차장  US200421         1  ...       N          0               0
# 69288   화봉공원 공영주차장  US200421         2  ...       N          0               0
# 69289    낙산해수욕장주차장  YY180001         1  ...       N          0               0
#
# ...

# %%
data.tail()
# Out:
#            STAT_NM   STAT_ID  CHGER_ID  ...  DEL_YN DEL_DETAIL  POWER_TYPE_all
# 69285  영남알프스복합웰컴센터  US200419         2  ...       N          0               0
# 69286   언양읍 행정복지센터  US200420         1  ...       N          0               0
# 69287   화봉공원 공영주차장  US200421         1  ...       N          0               0
# 69288   화봉공원 공영주차장  US200421         2  ...       N          0               0
# 69289    낙산해수욕장주차장  YY180001         1  ...       N          0               0
#
# [5 rows x 22 columns]

# %%
data.head()
# Out:
#        STAT_NM   STAT_ID  CHGER_ID  ...  DEL_YN DEL_DETAIL  POWER_TYPE_all
# 0     종묘 공영주차장  ME000001         1  ...       N          0        급속(50kW)
# 1    세종로 공영주차장  ME000002         1  ...       N          0        급속(50kW)
# 2   그랜드앰배서더 서울  ME000003         1  ...       N          0        급속(50kW)
# 3   한강진역 공영주차장  ME000004         1  ...       N          0        급속(50kW)
# 4  기아차 성동서비스센터  ME000005         1  ...       N          0        급속(50kW)
#
# [5 rows x 22 columns]

# %%
data.replace("급속(50kW)", 1)
data.replace("급속(100kW동시)", 1)
data.replace("급속(100kW멀티)", 1)
data.replace("급속(200kW멀티)", 1)
data.replace("급속(200kW동시)", 1)
data.replace("급속(400kW멀티)", 1)
data.replace("급속(400kW동시)", 1)
# Out:
#            STAT_NM   STAT_ID  CHGER_ID  ...  DEL_YN DEL_DETAIL  POWER_TYPE_all
# 0         종묘 공영주차장  ME000001         1  ...       N          0        급속(50kW)
# 1        세종로 공영주차장  ME000002         1  ...       N          0        급속(50kW)
# 2       그랜드앰배서더 서울  ME000003         1  ...       N          0        급속(50kW)
# 3       한강진역 공영주차장  ME000004         1  ...       N          0        급속(50kW)
# 4      기아차 성동서비스센터  ME000005         1  ...       N          0        급속(50kW)
# ...            ...       ...       ...  ...     ...        ...             ...
# 69285  영남알프스복합웰컴센터  US200419         2  ...       N          0               0
# 69286   언양읍 행정복지센터  US200420         1  ...       N          0               0
# 69287   화봉공원 공영주차장  US200421         1  ...       N          0               0
# 69288   화봉공원 공영주차장  US200421         2  ...       N          0               0
# 69289    낙산해수욕장주차장  YY180001         1  ...       N          0               0
#
# ...
