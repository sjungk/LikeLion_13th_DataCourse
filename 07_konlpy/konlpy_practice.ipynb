# %%
### 나눔 고딕 설치
# !apt-get update -qq   # 설치를 업데이트 
# !apt-get install fonts-nanum* -qq  # 설치한다. fonts-nanum*

# %%
# %matplotlib inline
import matplotlib as mpl # 기본 설정 만지는 용도
import matplotlib.pyplot as plt # 그래프 그리는 용도
import matplotlib.font_manager as fm # 폰트 관련 용도
import numpy as np

path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 설치된 나눔 글꼴중 원하는 녀석의 전체
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

# 우선 fm._rebuild() 를 해주고 # 폰트 매니저 재빌드가 필요하다.
fm._rebuild()
# Out:
# NanumGothic

# %%
# 데이터 준비
data = np.random.randint(-200, 100, 50).cumsum()

# 그래프를 그려 한글 확인
plt.plot(range(50), data, 'r')
plt.title('시간별 가격 추이')
# Out:
# Text(0.5, 1.0, '시간별 가격 추이')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.4 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 56.6 MB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import nltk
from konlpy.tag import Kkma

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import pandas as pd

# %%
text = open("샹치_댓글.csv").read()
text
#text = pd.read_csv("샹치_댓글.csv")
#text[1:100]
# Out:
# '댓글\n별로. 아니 스렉 짱 갯 아하하하\n젛았어여 저는ㅠ네네네\n"나만 강남스타일, 스모선수가 태권도소년 던지는거 별로였나...마블이 왜 한국 이렇게 넣었는지 모르겠음... 그리고 여주 목소리가 너무 ... 신경쓰였음 ㅠㅠ"\n마블영화중 유일하게 돈아깝다고 생각한 영화.. 믿고봤는데 사기당한 느낌.. 양조위의 연기력이 아까울뿐.. 중국판 디워 딱 그 이상이하도 아닌 뜬금없는 스토리와 연출.. 부디 마블은 정신차리고 중국산에서 벗어나길..\n중국풍 빼고 보면 기대이상 존잼입니다!! 액션 스케일 장난없네요!! 꼭 아맥으로 보시길추천!!\n전혀 기대 없이 본 영화인데 마블 영화중에 오랜만에 재미있게 봤음.. 서사적인 부분에서 좀 에러가 있지만.. 다른 마블영화도 비슷하니 패스~ 영상미나 액션은 정말 뛰어납니다 주인공도 보다보니 정가고 ㅋㅋㅋㅋ\n재미있는데 후반부에 갑자기 짱깨 무협 영화 보는 줄 알았음 급 짜게 식음… 나머지는 ㄱㅊ\n진짜 개실망. 이건중국영화다 보지마라\n양조위가 부릅니다너무나 많이 사랑한 죄~~\n마블 영화중 최고의 실패작시작부터 졸았다 끈금포 무협 로맨스씬에서는 그냥 소리지를뻔했다. 처음부터 끝까지 그냥 중국 sf판타지무협 영화였다 엔딩크레딧 2개 있다 안봐도 크게 의미없다 그냥 검색해서 내용만 알면 될듯\n솔직히 이정도 평점 받을 영화는 아니라고 봄...물론 한국사람들이 싫어하는 요소가 많은건 인정하고 본인도 별로였던 부분도 많았지만 액션과 영상미가 모든 걸 커버쳤다고 생각함\n마블 최악이다..여주인공은 원주누나 닮았고진짜 그래픽많은 중국영화 본거같았다무술은 이제 버리자..\n대박잼있어요!!! 꼭보세요\n중국 뭍어서 좀 반감 가지고 봤는데 액션씬 지립니다. 역시 믿고보는.마블이네요 근데 마지막에 최종보스는 좀 아쉬움\n근래 들어 본 영화 중에 가장 재밌네요 평점 낮은게 있길래 기대 안했는데 최곱니다\n한심한 2030 한남들 여기서도 중국영화 이 ㅈㄹ 떠네\n마블 영화중에 가장 실망스러웠음 / 액션은 볼만한데 마지막 전투신은 너무 허무함 다음 시리즈가 어떻게 이어질지 모르지만 모든 요소가 밋밋함.개인적이지만 남자 주인공과 친구가 매력적이지 않음 엄마 아빠가 더 매력적임. 팬던트가 중요한거 처럼 여기더니 별거 없음 뭔가 하
는게 너무 싫다. 저예산으로 급하게 만든건줄 알았는데 그전에 만든 마블영화들이랑 비슷한 예산… 정말? 예산이 비슷하다고? 맙소사… CG퀄리티를 보고도? 그냥 고퀄리티 온라인게임 같았어. 수준이 아이온? 블레이드소울정도?샹치는 정말 아! made in china & MARVEL마블 실망이다. 내가 제일 좋아하는 장르인데 이번편은 정말 많이 실망이다.\n솔직히 스토리 별루 마블이여서 봤음 확실한거 마블에서 아시아계 배우는 수현이 최고인거같음 킬링 타임용인듯 블랙팬서 아시아판이라고 하는 말이 있어서 기대좀 했는데.. 그냥 와호장룡1이 정말 대단했구나 하는 생각이 샹치 배우 골격때문에 근돼처럼 나옴\n중국 무술 미화하는데 진짜 MCU 영화가 아닌거같고 양조위밖에 안보임 주인공이 너무 임팩트 없음\n발돌릴때마다짜증..\n무기 안에 담겨진 \'중요한 메시지\' 때문에 2시간 동안 중국한 영화. 텐 링즈라는 무기에 대한 스토리와 개연성이 너무나 부족했고 풀어내는 과정이 아쉬웠음...\n재미없어서 처음으로 평저 달아봄\n영상미랑 ost 진짜 끝내주네요 ㅎㅎ극장에서 볼때 최적화된거 같아요!두번보러 갑니다 ㅎ\n마블 타이틀 빼고 보면 음....그냥 3류 중국 영화 ㅋㅋㅋ\n마블영화 별로 안좋아했는데 샹치보고 입문함\n"평 안좋게 남기신 분들은 물론 영화 자체에 흥미를 못 느낀 걸수도 있지만, 솔직히 중국 문화라 싫은 거 아닌가요?? 편협된 시각으로 바라보면 샹치는 마음에 안들수 밖에 없음. 근데 마블이 중국을 찬양하는 내용으로 제작한 것도 아니고 하나의 문화를 베이스로 멋진 스토리를 영상화 해낸 건데 반응이 좀 답답... 중국 자본 떡칠 전혀 아닙니다. 괜히 평점 보고 영화 안 보는 일 없기를...ㅠ"\n마블 쿠키때문에 봤는데 쿠키 3분 빼고 시간 아깝 ㅜ  아..3분도 아깝네..\n샹치를 보고 암이 나았습니다\n버스 액션 10각시탈 싸움 5샹치 여친 1샹치 엄마 10샹치 아빠 10마법 마을 1용가리 1\nㄹㅇ이거 왜 안 봄?? 액션신도 많아서 지루함 1도 없고 대존잼 ㅋ\n마블 가운데 가장 재미없음...\n기존 마블영화와는 다른 느낌이었어요\n""\n조금은 어색한 전개 하지만 확실한 연기력\n"내가 마블 영화는 여태껏 단 한편도 안빠지고 다 봤는데, 짱개 나오는 건 못보지. 그리고 감상포인트라니 영화도 안봤는데, 왜 찍으래? 모르겠다 ost만 줄께."\n아무 생각없이 재미로만 보면 근래 가장 재미있었음...\n진짜 마블영화중에 최악이에요\n마블류 어쩌다 보는데 샹치는 스토리가 재밋었다고 해야되나 쩃든 재밋게 잘봄!\n"스토리도 좋았고 영상미도 훌륭했으나, 아콰피나 극혐이라서 1점 줬습니다. 영화 보신분들은 어떤 느낌인지 아실 겁니다. 양조위가 샹치 역으로 대신 나왔으면 아마 엄청난 영화가 되지 않았을가 싶습니다."\n"마블이 중국 돈 받아서 어쩔 수 ...

# %%
from konlpy.tag import Okt
t = Okt()

# %%
doc_nouns = t.nouns(text)
print( len(doc_nouns) )
# Out:
# 5247

# %%
ko = nltk.Text(doc_nouns, name="샹치")
print(type(ko))
# Out:
# <class 'nltk.text.Text'>

# %%
type( ko.vocab() ), ko.vocab().most_common(20)
# Out:
# (nltk.probability.FreqDist,
#  [('영화', 265),
#   ('마블', 235),
#   ('중국', 175),
#   ('액션', 95),
#   ('양조위', 81),
#   ('그냥', 59),
#   ('스토리', 54),
#   ('진짜', 52),
#   ('샹치', 50),
#   ('생각', 45),
#   ('것', 43),
#   ('느낌', 41),
#   ('볼', 41),
#   ('중국영화', 38),
#   ('주인공', 35),
#   ('사람', 35),
#   ('평점', 34),
#   ('좀', 32),
#   ('이', 31),
#   ('무협', 27)])

# %%
most_fre = ko.vocab().most_common(70)
most_fre
# Out:
# [('영화', 265),
#  ('마블', 235),
#  ('중국', 175),
#  ('액션', 95),
#  ('양조위', 81),
#  ('그냥', 59),
#  ('스토리', 54),
#  ('진짜', 52),
#  ('샹치', 50),
#  ('생각', 45),
#  ('것', 43),
#  ('느낌', 41),
#  ('볼', 41),
#  ('중국영화', 38),
#  ('주인공', 35),
#  ('사람', 35),
#  ('평점', 34),
#  ('좀', 32),
#  ('이', 31),
#  ('무협', 27),
#  ('더', 25),
#  ('점', 25),
#  ('뭐', 25),
#  ('왜', 24),
#  ('처음', 24),
#  ('거', 24),
#  ('부분', 23),
#  ('별로', 22),
#  ('디워', 22),
#  ('기대', 22),
#  ('정말', 22),
#  ('배우', 22),
#  ('함', 21),
#  ('중간', 21),
#  ('안', 20),
#  ('재미', 20),
#  ('정도', 20),
#  ('돈', 19),
#  ('보고', 19),
#  ('임', 19),
#  ('영상', 18),
#  ('하나', 17),
#  ('역시', 16),
#  ('수', 16),
#  ('자본', 16),
#  ('그', 15),
#  ('다른', 15),
#  ('판타지', 15),
#  ('내용', 15),
#  ('듯', 15),
#  ('때문', 15),
#  ('한국', 14),
#  ('매력', 14),
#  ('내', 14),
#  ('용', 14),
#  ('히어로', 14),
#  ('문화', 14),
#  ('나', 13),
#  ('시작', 13),
#  ('개연', 13),
#  ('전', 13),
#  ('봄', 12),
#  ('무술', 12),
#  ('마지막', 12),
#  ('개인', 12),
#  ('눈', 12),
#  ('초반', 12),
#  ('도', 12),
#  ('연기', 12),
#  ('욕', 12)]

# %%
print( len( set( ko.tokens) ) )
# Out:
# 1519

# %%
plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %%
stop_words = ['분노', '영화', '액션', '시리즈', '진짜', 
              '더', '이', '거', '왜', '좀', '뭐', '임', '수', '정도' 
              '돈', '것', '다음', '질주', '그냥', '다른'
              '내', '용', '전' '말', '뭐', '애', '나', '듯', '편', '볼', '범', 
              '중', '로', '눈', '점', '함', '안', '돈', '급',
              '또','욕','도','봄', '씬', '저', '때', '전', '그',
              '만', '말', '내']

new_ko = []
for one_word in ko:
  if one_word not in stop_words:
    new_ko.append(one_word)

# %%
new_ko = nltk.Text(new_ko, name='샹치')
plt.figure(figsize=(12,6))
new_ko.plot(50)

# %%
plt.figure(figsize=(15,8))
new_ko.dispersion_plot(['스토리','마블','중국영화','재미'])

# %%
import numpy as np
from PIL import Image

# %%
SC = np.array(Image.open("Robot.png"))

# %%
data = new_ko.vocab().most_common(100)

# %%
wc = WordCloud(background_color='white', 
               max_words=200,
               mask=SC,   
               contour_width=3, 
               contour_color="steelblue", 
               font_path=path).generate_from_frequencies(dict(data))

# %%
plt.figure(figsize=(12,8))
plt.imshow(wc)
plt.axis('off')
plt.show()
